# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\AL\Downloads\bank2.csv")

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
sns.barplot(x='marital',y='age',hue='loan',data=df,errorbar=None)
plt.ylabel("Average age")
plt.xlabel("Marital status")
plt.title("Age by loan and marital status")
plt.show()

# %%
sns.countplot(x=df['housing'])
# Out:
# <Axes: xlabel='housing', ylabel='count'>

# %%
# Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['age'].dropna(), kde=True)
plt.title('Age Distribution')
plt.show()
# Out:
# C:\Users\AL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Job Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='job', data=df)
plt.title('Job Distribution')
plt.xticks(rotation=45)
plt.show()
